# %%
import numpy as np
import matplotlib.pyplot as plt
import heapq

def out_of_bounds(i, j, maze):
    return i < 0 or j < 0 or i >= len(maze) or j >= len(maze[0])

class Node():
    moves = [(0, 1), (0, -1), (1, 0), (-1, 0)]
    def __init__(self, pos: tuple[int, int]):
        self.pos = pos
        self.visited = False
        self.distance = float('inf')
        self.neighbors: list[Node] = []
        
    def __add__(self, move: tuple[int, int]) -> tuple[int, int]:
        return self.pos[0] + move[0], self.pos[1] + move[1]
    
    def __eq__(self, other):
        # if other is not a node, return false
        if not isinstance(other, Node):
            return False
        return self.pos == other.pos
    
    def __lt__(self, other):
        self.pos < other.pos
    
    def __str__(self):
        return f'{self.pos}'
    
    def __repr__(self):
        return self.__str__()
    
    def __hash__(self):
        return hash(self.pos)

class Maze():
    def __init__(self, maze: np.ndarray[np.ndarray[Node]], start: Node, end: Node, walls: list[tuple[int, int]]):
        self.maze = maze
        self.start = start
        self.end = end
        self.jumpable_walls = self.get_jumpable_walls(walls)

    def reset(self):
        for i in range(self.maze.shape[0]):
            for j in range(self.maze.shape[1]):
                if self.maze[i][j] == 0:
                    continue
                self.maze[i][j].visited = False
                self.maze[i][j].distance = float('inf') if self.maze[i][j] != self.start else 0


    def tally_cheats(self, min_steps_saved: int):
        # for each jumpable wall, remove it and run djikstra
        # if the distance is steps_saved less than vanilla, it's a cheat
        cheatlist = []

        vanilla_dist = self.djikstra()

        for n, wall in enumerate(self.jumpable_walls, 1):
            self.reset()
            fake_wall = Node(wall)
            self.maze[wall[0]][wall[1]] = fake_wall
            cheat_dist = self.djikstra()
            if cheat_dist == -1:
                continue
            if vanilla_dist - cheat_dist >= min_steps_saved:
                cheatlist.append({"wall": wall, "steps_saved": vanilla_dist - cheat_dist})
            self.maze[wall[0]][wall[1]] = 0
            print(f"{len(cheatlist)} cheats found | {n/len(self.jumpable_walls) * 100:.2f}%", end='\r')

        print()
        return cheatlist

    def djikstra(self):
        self.set_neighbors()
        queue: list[Node] = []
        heapq.heappush(queue, (0, self.maze[self.start.pos[0]][self.start.pos[1]]))

        while len(queue) > 0:
            dist, node = heapq.heappop(queue)
            if node.visited:
                continue

            node.visited = True
            if node.pos == self.end.pos:
                return dist

            for neighbor in node.neighbors:
                if not neighbor.visited:
                    heapq.heappush(queue, (dist + 1, neighbor))
            
        return -1
    
    def set_neighbors(self):
        for i in range(self.maze.shape[0]):
            for j in range(self.maze.shape[1]):
                if self.maze[i][j] == 0:
                    continue

                self.maze[i][j].neighbors = self.get_legal_moves(self.maze[i][j])

    def get_legal_moves(self, node: Node) -> list[Node]:
        # can move up down left right
        n_moves = []
        for move in Node.moves:
            new_pos = node + move
            if not out_of_bounds(new_pos[0], new_pos[1], self.maze):
                n_node = self.maze[new_pos[0]][new_pos[1]]
                if n_node != 0:
                    n_moves.append(self.maze[new_pos[0]][new_pos[1]])

        return n_moves
                
    def get_jumpable_walls(self, walls: list[tuple[int, int]]) -> list[tuple[int, int]]:
        # if wall is surrounded by walls, remove it
        valid_coords = []
        for wall in walls:
            for move in Node.moves:
                jump = wall[0] + move[0], wall[1] + move[1]
                if out_of_bounds(jump[0], jump[1], self.maze):
                    continue

                if self.maze[jump[0]][jump[1]] == 0:
                    continue
                
                # at this point we know we can jump from the wall to stable ground
                # but is there stable ground behind us?
                opposite_move = (-move[0], -move[1])
                prev = wall[0] + opposite_move[0], wall[1] + opposite_move[1]
                if out_of_bounds(prev[0], prev[1], self.maze):
                    continue # out of bounds
                
                if self.maze[prev[0]][prev[1]] == 0:
                    continue # more wall

                # it's jumpable
                valid_coords.append(wall)
                break
        
        return valid_coords

    def plot(self, highlight_coord=None):
        m = [[0 if self.maze[i][j] == 0 else 1 for j in range(len(self.maze))] for i in range(len(self.maze[0]))]
        for wall in self.jumpable_walls:
            plt.scatter(wall[1], wall[0], c='r', marker='o', s=40)
        plt.imshow(m)
        plt.scatter(self.start.pos[1], self.start.pos[0], c='r', marker='4', s=60)
        plt.scatter(self.end.pos[1], self.end.pos[0], c='g', marker='8', s=60)
        if highlight_coord:
            plt.scatter(highlight_coord[1], highlight_coord[0], c='y', marker='x', s=120)

        plt.show()
            
    def __str__(self):
        return "\n".join(["".join(["#" if c == 0 else "S" if c == self.start else "E" if c == self.end else "." for c in row]) for row in self.maze])
    
    def __repr__(self):
        return self.__str__()

# %%
# reuse maze and djikstra from previous problem
def simulate(filename: str):
    maze = []
    wall_coords = []
    start = None
    end = None
    with open(filename) as f:
        i = 0
        for line in f.readlines():
            row = []
            j = 0
            for c in line.strip():
                if c == '#':
                    row.append(0)
                    wall_coords.append((i, j))
                elif c == '.':
                    row.append(Node((i, j)))
                elif c == 'S':
                    start = Node((i, j))
                    start.distance = 0
                    row.append(start)
                elif c == 'E':
                    end = Node((i, j))
                    row.append(end)
                j += 1
            maze.append(np.array(row))
            i += 1

    return Maze(np.array(maze), start, end, wall_coords)

maze = simulate('input.txt')
# maze.plot()
cheatlist = maze.tally_cheats(100)
print(f"{len(cheatlist)} cheats found")
# Out:
# 1404 cheats found | 100.00%
# 1404 cheats found

# %%
# order by steps_saved
sorted_cheats = sorted(cheatlist, key=lambda x: x['steps_saved'], reverse=True)

# group by steps_saved
grouped_cheats = {}
for cheat in sorted_cheats:
    if cheat['steps_saved'] not in grouped_cheats:
        grouped_cheats[cheat['steps_saved']] = []
    grouped_cheats[cheat['steps_saved']].append(cheat)

for steps_saved, cheats in reversed(grouped_cheats.items()):
    print(f"There are {len(cheats)} cheats that save {steps_saved} picoseconds")
# Out:
# There are 22 cheats that save 100 picoseconds
# There are 8 cheats that save 102 picoseconds
# There are 22 cheats that save 104 picoseconds
# There are 9 cheats that save 106 picoseconds
# There are 23 cheats that save 108 picoseconds
# There are 9 cheats that save 110 picoseconds
# There are 27 cheats that save 112 picoseconds
# There are 14 cheats that save 114 picoseconds
# There are 25 cheats that save 116 picoseconds
# There are 8 cheats that save 118 picoseconds
# There are 18 cheats that save 120 picoseconds
# There are 8 cheats that save 122 picoseconds
# There are 18 cheats that save 124 picoseconds
# There are 7 cheats that save 126 picoseconds
# There are 17 cheats that save 128 picoseconds
# There are 10 cheats that save 130 picoseconds
# There are 19 cheats that save 132 picoseconds
# There are 7 cheats that save 134 picoseconds
# There are 11 cheats that save 136 picoseconds
# There are 5 cheats that save 138 picoseconds
# There are 14 cheats that save 140 picoseconds
# There are 6 cheats that save 142 picoseconds
# There are 13 cheats that save 144 picoseconds
# There are 4 cheats that save 146 picoseconds
# There are 13 cheats that save 148 picoseconds
# There are 4 cheats that save 150 picoseconds
# There are 12 cheats that save 152 picoseconds
# There are 2 cheats that save 154 picoseconds
# There are 12 cheats that save 156 picoseconds
# There are 6 cheats that save 158 picoseconds
# There are 15 cheats that save 160 picoseconds
# There are 9 cheats that save 162 picoseconds
# There are 19 cheats that save 164 picoseconds
# There are 8 cheats that save 166 picoseconds
# There are 15 cheats that save 168 picoseconds
# There are 8 cheats that save 170 picoseconds
# There are 18 cheats that save 172 picoseconds
# There are 11 cheats that save 174 picoseconds
# There are 19 cheats that save 176 picoseconds
# There are 10 cheats that save 178 picoseconds
# There are 18 cheats that save 180 picoseconds
# There are 7 cheats that save 182 picoseconds
# There are 13 cheats that save 184 picoseconds
# There are 3 cheats that save 186 picoseconds
# There are 11 cheats that save 188 picoseconds
# There are 4 cheats that save 190 picoseconds
# There are 10 cheats that save 192 picoseconds
# There are 5 cheats that save 194 picoseconds
# There are 9 cheats that save 196 picoseconds
# There are 2 cheats that save 198 picoseconds
# There are 7 cheats that save 200 picoseconds
# There are 3 cheats that save 202 picoseconds
# There are 17 cheats that save 204 picoseconds
# There are 11 cheats that save 206 picoseconds
# There are 19 cheats that save 208 picoseconds
# There are 6 cheats that save 210 picoseconds
# There are 16 cheats that save 212 picoseconds
# There are 6 cheats that save 214 picoseconds
# There are 13 cheats that save 216 picoseconds
# There are 5 cheats that save 218 picoseconds
# There are 11 cheats that save 220 picoseconds
# There are 1 cheats that save 222 picoseconds
# There are 12 cheats that save 224 picoseconds
# There are 4 cheats that save 226 picoseconds
# There are 6 cheats that save 228 picoseconds
# There are 3 cheats that save 230 picoseconds
# There are 11 cheats that save 232 picoseconds
# There are 3 cheats that save 234 picoseconds
# There are 8 cheats that save 236 picoseconds
# There are 3 cheats that save 238 picoseconds
# There are 7 cheats that save 240 picoseconds
# There are 3 cheats that save 242 picoseconds
# There are 13 cheats that save 244 picoseconds
# There are 3 cheats that save 246 picoseconds
# There are 12 cheats that save 248 picoseconds
# There are 7 cheats that save 250 picoseconds
# There are 15 cheats that save 252 picoseconds
# There are 6 cheats that save 254 picoseconds
# There are 12 cheats that save 256 picoseconds
# There are 4 cheats that save 258 picoseconds
# There are 11 cheats that save 260 picoseconds
# There are 8 cheats that save 262 picoseconds
# There are 14 cheats that save 264 picoseconds
# There are 3 cheats that save 266 picoseconds
# There are 10 cheats that save 268 picoseconds
# There are 2 cheats that save 270 picoseconds
# There are 7 cheats that save 272 picoseconds
# There are 1 cheats that save 274 picoseconds
# There are 8 cheats that save 276 picoseconds
# There are 5 cheats that save 278 picoseconds
# There are 9 cheats that save 280 picoseconds
# There are 2 cheats that save 282 picoseconds
# There are 7 cheats that save 284 picoseconds
# There are 1 cheats that save 286 picoseconds
# There are 9 cheats that save 288 picoseconds
# There are 1 cheats that save 868 picoseconds
# There are 1 cheats that save 1008 picoseconds
# There are 1 cheats that save 1010 picoseconds
# There are 1 cheats that save 1012 picoseconds
# There are 1 cheats that save 1014 picoseconds
# There are 1 cheats that save 1016 picoseconds
# There are 1 cheats that save 1068 picoseconds
# There are 1 cheats that save 1070 picoseconds
# There are 1 cheats that save 1072 picoseconds
# There are 1 cheats that save 1116 picoseconds
# There are 1 cheats that save 1118 picoseconds
# There are 1 cheats that save 1120 picoseconds
# There are 1 cheats that save 1124 picoseconds
# There are 1 cheats that save 1132 picoseconds
# There are 1 cheats that save 1134 picoseconds
# There are 1 cheats that save 1136 picoseconds
# There are 1 cheats that save 1156 picoseconds
# There are 1 cheats that save 1160 picoseconds
# There are 1 cheats that save 1184 picoseconds
# There are 1 cheats that save 1186 picoseconds
# There are 1 cheats that save 1188 picoseconds
# There are 1 cheats that save 1212 picoseconds
# There are 1 cheats that save 1214 picoseconds
# There are 1 cheats that save 1216 picoseconds
# There are 1 cheats that save 1236 picoseconds
# There are 1 cheats that save 1238 picoseconds
# There are 1 cheats that save 1240 picoseconds
# There are 1 cheats that save 1242 picoseconds
# There are 1 cheats that save 1244 picoseconds
# There are 1 cheats that save 1246 picoseconds
# There are 1 cheats that save 1248 picoseconds
# There are 1 cheats that save 1284 picoseconds
# There are 1 cheats that save 1286 picoseconds
# There are 1 cheats that save 1288 picoseconds
# There are 1 cheats that save 1316 picoseconds
# There are 1 cheats that save 1320 picoseconds
# There are 1 cheats that save 1322 picoseconds
# There are 1 cheats that save 1324 picoseconds
# There are 1 cheats that save 1388 picoseconds
# There are 1 cheats that save 1390 picoseconds
# There are 1 cheats that save 1392 picoseconds
# There are 1 cheats that save 1456 picoseconds
# There are 2 cheats that save 1460 picoseconds
# There are 1 cheats that save 1462 picoseconds
# There are 2 cheats that save 1464 picoseconds
# There are 1 cheats that save 1468 picoseconds
# There are 2 cheats that save 1476 picoseconds
# There are 1 cheats that save 1478 picoseconds
# There are 1 cheats that save 1480 picoseconds
# There are 1 cheats that save 1496 picoseconds
# There are 1 cheats that save 1504 picoseconds
# There are 1 cheats that save 1528 picoseconds
# There are 1 cheats that save 1530 picoseconds
# There are 1 cheats that save 1532 picoseconds
# There are 1 cheats that save 1556 picoseconds
# There are 1 cheats that save 1558 picoseconds
# There are 1 cheats that save 1560 picoseconds
# There are 1 cheats that save 1712 picoseconds
# There are 1 cheats that save 1720 picoseconds
# There are 1 cheats that save 1722 picoseconds
# There are 1 cheats that save 1724 picoseconds
# There are 1 cheats that save 1768 picoseconds
# There are 1 cheats that save 1770 picoseconds
# There are 1 cheats that save 1772 picoseconds
# There are 1 cheats that save 1780 picoseconds
# There are 1 cheats that save 1782 picoseconds
# There are 1 cheats that save 1784 picoseconds
# There are 1 cheats that save 1786 picoseconds
# There are 1 cheats that save 1788 picoseconds
# There are 1 cheats that save 1876 picoseconds
# There are 1 cheats that save 1878 picoseconds
# There are 1 cheats that save 1880 picoseconds
# There are 1 cheats that save 1912 picoseconds
# There are 1 cheats that save 1914 picoseconds
# There are 1 cheats that save 1916 picoseconds
# There are 1 cheats that save 1988 picoseconds
# There are 1 cheats that save 1990 picoseconds
# There are 1 cheats that save 1992 picoseconds
# There are 1 cheats that save 1996 picoseconds
# There are 1 cheats that save 1998 picoseconds
# There are 2 cheats that save 2000 picoseconds
# There are 2 cheats that save 2004 picoseconds
# There are 1 cheats that save 2006 picoseconds
# There are 1 cheats that save 2008 picoseconds
# There are 1 cheats that save 2010 picoseconds
# There are 1 cheats that save 2012 picoseconds
# There are 1 cheats that save 2014 picoseconds
# There are 1 cheats that save 2016 picoseconds
# There are 1 cheats that save 2072 picoseconds
# There are 1 cheats that save 2074 picoseconds
# There are 1 cheats that save 2076 picoseconds
# There are 1 cheats that save 2078 picoseconds
# There are 1 cheats that save 2080 picoseconds
# There are 1 cheats that save 2680 picoseconds
# There are 1 cheats that save 2684 picoseconds
# There are 1 cheats that save 2686 picoseconds
# There are 1 cheats that save 2688 picoseconds
# There are 1 cheats that save 2690 picoseconds
# There are 1 cheats that save 2692 picoseconds
# There are 1 cheats that save 2694 picoseconds
# There are 1 cheats that save 2696 picoseconds
# There are 1 cheats that save 2698 picoseconds
# There are 1 cheats that save 2700 picoseconds
# There are 1 cheats that save 4088 picoseconds
# There are 1 cheats that save 4428 picoseconds
# There are 1 cheats that save 4440 picoseconds
# There are 1 cheats that save 4452 picoseconds
# There are 1 cheats that save 4454 picoseconds
# There are 1 cheats that save 4456 picoseconds
# There are 1 cheats that save 4488 picoseconds
# There are 1 cheats that save 4504 picoseconds
# There are 1 cheats that save 4506 picoseconds
# There are 1 cheats that save 4508 picoseconds
# There are 1 cheats that save 7212 picoseconds
# There are 1 cheats that save 7216 picoseconds
# There are 1 cheats that save 7300 picoseconds
# There are 1 cheats that save 7302 picoseconds
# There are 1 cheats that save 7304 picoseconds
# There are 1 cheats that save 7312 picoseconds
# There are 1 cheats that save 7316 picoseconds
# There are 1 cheats that save 7828 picoseconds
# There are 1 cheats that save 7830 picoseconds
# There are 1 cheats that save 7832 picoseconds
# There are 1 cheats that save 7840 picoseconds
# There are 1 cheats that save 7842 picoseconds
# There are 1 cheats that save 7844 picoseconds
# There are 1 cheats that save 7852 picoseconds
# There are 1 cheats that save 9056 picoseconds
# There are 1 cheats that save 9058 picoseconds
# There are 1 cheats that save 9060 picoseconds
# There are 1 cheats that save 9068 picoseconds
# There are 1 cheats that save 9070 picoseconds
# There are 1 cheats that save 9072 picoseconds
# There are 1 cheats that save 9112 picoseconds
# There are 1 cheats that save 9132 picoseconds
# There are 1 cheats that save 9140 picoseconds
# There are 1 cheats that save 9142 picoseconds
# There are 1 cheats that save 9144 picoseconds
# There are 1 cheats that save 9152 picoseconds
# There are 1 cheats that save 9154 picoseconds
# There are 1 cheats that save 9156 picoseconds
# There are 1 cheats that save 9168 picoseconds
# There are 1 cheats that save 9170 picoseconds
# There are 1 cheats that save 9172 picoseconds
# There are 1 cheats that save 9180 picoseconds
# There are 1 cheats that save 9208 picoseconds
# There are 1 cheats that save 9220 picoseconds
# There are 1 cheats that save 9222 picoseconds
# There are 1 cheats that save 9224 picoseconds
